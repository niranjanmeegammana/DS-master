# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import pandas as pd

# %% [markdown]
# ### CSV Input syntax

# %%
customers_url="https://raw.githubusercontent.com/ShilpaSayuraML/Python-for-Finance/master/Chapter%202/Pandas/Customers.csv"
dataframe = pd.read_csv(customers_url)

# %% [markdown]
# ### CSV Output returned

# %%
dataframe.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.to_csv('customer_copy.csv',index=False)

# %% [markdown]
# ## Excel
# Pandas is able to read and write from and in a excel file

# %% [markdown]
# ### Excel Input

# %%
import pandas as pd
import requests

# %%
excel_url='https://github.com/ShilpaSayuraML/Python-for-Finance/blob/master/Chapter%202/Pandas/Sample.xlsx'
df=pd.read_excel(excel,sheet_name='Sample')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-dcf6512205c7> in <module>
#       1 excel_url='https://github.com/ShilpaSayuraML/Python-for-Finance/blob/master/Chapter%202/Pandas/Sample.xlsx'
# ----> 2 df=pd.read_excel(excel_url,sheet_name='Sample')
#       3 df.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# Pandas can read table from the html.

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   December 5, 2017
