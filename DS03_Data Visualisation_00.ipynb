# %%
#Data 
users = [
 { "id": 0, "name": "Am" },
 { "id": 1, "name": "Duma" },
 { "id": 2, "name": "Cima" },
 { "id": 3, "name": "Em" },
 { "id": 4, "name": "Tim" },
 { "id": 5, "name": "Kuma" }
]

# %%
users
# Out:
# [{'id': 0, 'name': 'Am'},
#  {'id': 1, 'name': 'Duma'},
#  {'id': 2, 'name': 'Cima'},
#  {'id': 3, 'name': 'Em'},
#  {'id': 4, 'name': 'Tim'},
#  {'id': 5, 'name': 'Kuma'}]

# %%
friendships = [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3), (3, 4),
 (4, 5)]

# %% [markdown]
# ![Screenshot_20230208-185455-01.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Salaries and Experience

# %%
salaries= [83000, 88000, 48000,76000, 60000]
experience=[10, 11, 1,7, 6]

# %%
import matplotlib.pyplot as plt
x=salaries
y=experience
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)
x = np.random.normal(size=1000)

plt.hist(x, density=True, bins=30)  # density=False would make counts
plt.ylabel('Frequency')
plt.xlabel('Data');

# %% [markdown]
# [link : example plots](https://matplotlib.org/stable/gallery/index.html)
